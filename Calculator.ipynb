# %% [markdown]
# # Calculator

# %%
def Calculator():
    history = []

    while True:
        print("\n------------- Calculator -------------")
        print("1. Addition")
        print("2. Subtraction")
        print("3. Multiplication")
        print("4. Division")
        print("5. Exit")

        choice = int(input("Enter The Choice (1-5): "))

        if choice == 5:
            print("Calculator Closed 🚪")
            break

        if choice in [1, 2, 3, 4]:
            num1 = float(input("Enter The First Number: "))
            num2 = float(input("Enter The Second Number: "))

        if choice == 1:
            result = num1 + num2
            print(f"Addition of {num1} and {num2} is : {result}")
            history.append(f"{num1} + {num2} = {result}")

        elif choice == 2:
            result = num1 - num2
            print(f"Subtraction of {num1} and {num2} is : {result}")
            history.append(f"{num1} - {num2} = {result}")

        elif choice == 3:
            result = num1 * num2
            print(f"Multiplication of {num1} and {num2} is : {result}")
            history.append(f"{num1} × {num2} = {result}")

        elif choice == 4:
            if num2 != 0:
                result = num1 / num2
                print(f"Division of {num1} and {num2} is : {result}")
                history.append(f"{num1} ÷ {num2} = {result}")
            else:
                print("❌ Division by Zero Not Possible")

        else:
            print("❗ Invalid Choice")

    print("\n📜 Calculation History:")
    for i, record in enumerate(history, start=1):
        print(f"{i}. {record}")


Calculator()
# Out:
# ------------- Calculator -------------
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter The Choice (1-5):  1
# Enter The First Number:  34.678
# Enter The Second Number:  4672.56
# Addition of 34.678 and 4672.56 is : 4707.238
#
# ------------- Calculator -------------
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter The Choice (1-5):  3
# Enter The First Number:  45.7890
# Enter The Second Number:  556
# Multiplication of 45.789 and 556.0 is : 25458.684
#
# ------------- Calculator -------------
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter The Choice (1-5):  2
# Enter The First Number:  123.45
# Enter The Second Number:  569
# Subtraction of 123.45 and 569.0 is : -445.55
#
# ------------- Calculator -------------
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter The Choice (1-5):  4
# Enter The First Number:  789
# Enter The Second Number:  234
# Division of 789.0 and 234.0 is : 3.371794871794872
#
# ------------- Calculator -------------
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter The Choice (1-5):  5
# Calculator Closed 🚪
#
# 📜 Calculation History:
# 1. 34.678 + 4672.56 = 4707.238
# 2. 45.789 × 556.0 = 25458.684
# 3. 123.45 - 569.0 = -445.55
# 4. 789.0 ÷ 234.0 = 3.371794871794872
